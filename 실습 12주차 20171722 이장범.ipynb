# %% [markdown]
# # 실습 12주차
# 20171722 이장범

# %%
import numpy as np
import matplotlib.pyplot as plt 
t= np.linspace(0,10.01,100)
x=np.arange(0,10.01,100)
y=np.sin(t)
z=np.sin(2*t)
plt.subplot(211)
plt.title("sin(t) and sin(2t)")
plt.plot(t,y,'r')
plt.plot(t,z,'b--')
plt.axhline(-1,-0.75,1,color="lightgray",linewidth=1)
plt.axhline(-0.75,-0.5,1,color="lightgray",linewidth=1)
plt.axhline(-0.5,-0.25,1,color="lightgray",linewidth=1)
plt.axhline(-0.25,0,1,color="lightgray",linewidth=1)
plt.axhline(0,0.25,1,color="lightgray",linewidth=1)
plt.axhline(0,-0.25,1,color="lightgray",linewidth=1)
plt.axhline(0.5,0.25,1,color="lightgray",linewidth=1)
plt.axhline(0.5,0.75,1,color="lightgray",linewidth=1)
plt.axhline(0.25,0.5,0,color="lightgray",linewidth=1)
plt.axhline(0.25,0.5,1,color="lightgray",linewidth=1)
plt.axhline(0.75,0.5,0,color="lightgray",linewidth=1)
plt.axhline(0.5,0.75,0,color="lightgray",linewidth=1)
plt.axhline(1,0.75,0,color="lightgray",linewidth=1)
plt.axhline(1,0.75,1,color="lightgray",linewidth=1)
plt.axhline(0.75,0.5,1,color="lightgray",linewidth=1)

plt.axvline(2,4,0,color="lightgray",linewidth=1)
plt.axvline(0,2,0,color="lightgray",linewidth=1)
plt.axvline(6,4,0,color="lightgray",linewidth=1)
plt.axvline(8,6,0,color="lightgray",linewidth=1)
plt.axvline(10,8,0,color="lightgray",linewidth=1)
plt.axvline(12,10,0,color="lightgray",linewidth=1)
plt.xticks(np.arange(0,10,2))
plt.yticks(np.arange(-1,1.25,0.25))
e=np.exp(-t)
plt.subplot(212)

plt.title("exp(-t)")
plt.xlabel("Time(sec)")
plt.plot(t,e,'black',label="exp(t)")
plt.axvline(2,4,0,color="lightgray",linewidth=1)
plt.axvline(4,6,1,color="lightgray",linewidth=1)
plt.axvline(4,6,0,color="lightgray",linewidth=1)
plt.axvline(6,4,0,color="lightgray",linewidth=1)
plt.axvline(0,2,0,color="lightgray",linewidth=1)
plt.axvline(0,2,1,color="lightgray",linewidth=1)
plt.axvline(8,6,0,color="lightgray",linewidth=1)
plt.axvline(10,8,0,color="lightgray",linewidth=1)

plt.axhline(0,0.2,0,color="lightgray",linewidth=1)
plt.axhline(0,0.2,1,color="lightgray",linewidth=1)
plt.axhline(0.2,0.4,0,color="lightgray",linewidth=1)
plt.axhline(0.4,0.6,1,color="lightgray",linewidth=1)
plt.axhline(0.6,0.8,0,color="lightgray",linewidth=1)
plt.axhline(0.2,0.4,1,color="lightgray",linewidth=1)
plt.axhline(0.8,0.6,0,color="lightgray",linewidth=1)
plt.axhline(0.6,0.8,1,color="lightgray",linewidth=1)
plt.axhline(0.4,0.6,0,color="lightgray",linewidth=1)
plt.axhline(1,0.8,0,color="lightgray",linewidth=1)
plt.axhline(1,0.8,1,color="lightgray",linewidth=1)
plt.axhline(0.8,0.6,1,color="lightgray",linewidth=1)
plt.yticks(np.arange(0,1.2,0.2))
plt.xticks(np.arange(0,12,2))
# Out:
# ([<matplotlib.axis.XTick at 0x1f27e5c3be0>,
# ...
#  <a list of 6 Text major ticklabel objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt

t=np.linspace(-np.pi, np.pi, 200)
y1=np.sin(t)
y2=np.cos(t)

plt.plot(t,y1,label="sin(t)",color='red')
plt.plot(t,y2,label="cos(t)",color='blue')
plt.xlabel("Time(rad)")
plt.ylabel("Outputs")
plt.title("Trigonometric functions")
plt.legend()
plt.xticks(np.arange(['$\-pi$','$-\pi$'/2,'0','$\pi$'/2,'$\pi$'])
# Out:
#   File "<ipython-input-163-1f75fd6be791>", line 14
#     plt.xticks(np.arange(['$\-^pi$','$-\^pi$'/2,'0','$\^pi$'/2,'$\^pi$'])
#                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
import matplotlib.pyplot as plt
import numpy as np

def millions(x):
    return '$%1.1fM' % (x*le-6)

np.random.seed(19680801)

plt.title("Random outputs")
a=np.random.randint(50 or 30 ,size=20)
b=np.random.randint(30, size=20)
plt.xlabel("Samples")

plt.plot(a,'+',color='g')
plt.plot(b,'x',color='cyan')
plt.axvline(0,5,1,color="lightgray",linewidth=1)
plt.axvline(5,10,1,color="lightgray",linewidth=1)
plt.axvline(10,15,1,color="lightgray",linewidth=1)
plt.axvline(15,20,1,color="lightgray",linewidth=1)
plt.axvline(0,5,0,color="lightgray",linewidth=1)
plt.axvline(5,10,0,color="lightgray",linewidth=1)
plt.axvline(10,15,0,color="lightgray",linewidth=1)
plt.axvline(15,20,0,color="lightgray",linewidth=1)

plt.axhline(0,10,1,color="lightgray",linewidth=1)
plt.axhline(10,20,1,color="lightgray",linewidth=1)
plt.axhline(20,30,1,color="lightgray",linewidth=1)
plt.axhline(40,50,1,color="lightgray",linewidth=1)
plt.axhline(0,10,0,color="lightgray",linewidth=1)
plt.axhline(10,20,0,color="lightgray",linewidth=1)
plt.axhline(20,30,0,color="lightgray",linewidth=1)
plt.axhline(30,40,1,color="lightgray",linewidth=1)
plt.axhline(30,40,0,color="lightgray",linewidth=1)
plt.axhline(40,50,0,color="lightgray",linewidth=1)
plt.axhline(30,40,0,color="lightgray",linewidth=1)

plt.xticks(np.arange(0,25,5))
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'cherry', 'banana' ,'apple','grape','pear','guaba','orange'
sizes = [41.7 ,18.3 ,10.4 ,7.0 ,3.0 ,15.0 ,4.6]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
result=0

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %%
result1=0
result2=0

def add1(num):
    global result1
    result1+=num
    return result1
def add2(num):
    global result2
    result2 +=num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %%
def sub(self, num):
    self.result-=num
    return self.result

# %%
class Cookie:
    pass
a= Cookie()
b= Cookie()
a= FourCal()
a.setdata(4,2)
print(a.add())
print(a.mul())
print(a.sub())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-7aa057a38135> in <module>
#       3 a= Cookie()
#       4 b= Cookie()
# ----> 5 a= FourCal()
#       6 a.setdata(4,2)
#       7 print(a.add())
#
# NameError: name 'FourCal' is not defined

# %%
a.setdata(4,2)
print(a.add())
print(a.mul())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-cc2f701831e6> in <module>
# ----> 1 a.setdata(4,2)
#       2 print(a.add())
#       3 print(a.mul())
#
# AttributeError: 'Cookie' object has no attribute 'setdata'

# %%
class FourCal:
    pass
a=FourCal()
type(a)
# Out:
# __main__.FourCal

# %%
class FourCal:
    def setdata(self,first,second):
        self.first= first
        self.second= second

# %%
def setdata(self,first,second):
    self.first=first
    self.second=second
a=FourCal()
a.setdata(4,2)
print(a.first)
print(a.second)
# Out:
# 4
# 2

# %%
a=FourCal()
b=FourCal()
a.setdata(4,2)
print(a.first)
b.setdata(3,7)
print(b.first)
print(a.first)
# Out:
# 4
# 3
# 4

# %%
a=FourCal()
b=FourCal()

a.setdata(4,2)
b.setdata(3,7)

print(id(a.first))
print(id(b.first))
# Out:
# 140730606303104
# 140730606303072

# %%
class FourCal:
    def setdata(self,first,second):
        self.first= first
        self.second= second
    def add(self):
        result= self.first+ self.second
        return result

# %%
a= FourCal()
a.setdata(4,2)
print(a.add())
# Out:
# 6

# %%
def add(self):
    result=self.first+self.second
    return result
result= self.first +self.second
result=a.first+a.second
result= 4 +2
print(a.add())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-bc1b8f3a4239> in <module>
#       2     result=self.first+self.second
#       3     return result
# ----> 4 result= self.first +self.second
#       5 result=a.first+a.second
#       6 result= 4 +2
#
# NameError: name 'self' is not defined

# %%
class FourCal:
...     def setdata(self, first, second):
...         self.first = first
...         self.second = second
...     def add(self):
...         result = self.first + self.second
...         return result
...     def mul(self):
...         result = self.first * self.second
...         return result
...     def sub(self):
...         result = self.first - self.second
...         return result
...     def div(self):
...         result = self.first / self.second
...         return result
...
a= FourCal()
b= FourCal()
a.setdata(4,2)
b.setdata(3,8)
print(a.add())
print(a.mul())
print(a.sub())
print(a.div())
print(b.add())
print(b.mul())
print(b.sub())
print(b.div())
a=FourCal()
a.add()
# Out:
# 6
# 8
# 2
# 2.0
# 11
# 24
# -5
# 0.375
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-a4db99a7ea08> in <module>
#      29 print(b.div())
#      30 a=FourCal()
# ---> 31 a.add()
#
# <ipython-input-129-a4db99a7ea08> in add(self)
#       4         self.second = second
#       5     def add(self):
# ----> 6         result = self.first + self.second
#       7         return result
#       8     def mul(self):
#
# AttributeError: 'FourCal' object has no attribute 'first'

# %%
class FourCal:
...     def __init__(self, first, second):
...         self.first = first
...         self.second = second
...     def setdata(self, first, second):
...         self.first = first
...         self.second = second
...     def add(self):
...         result = self.first + self.second
...         return result
...     def mul(self):
...         result = self.first * self.second
...         return result
...     def sub(self):
...         result = self.first - self.second
...         return result
...     def div(self):
...         result = self.first / self.second
...         return result

def __init__(self, first, second):
    self.first = first
    self.second = second
    
a = FourCal(4, 2)
print(a.first)
print(a.second)
print(a.add())
print(a.div())
# Out:
# 4
# 2
# 6
# 2.0

# %%
class MoreFourCal(FourCal):
    pass
a= MoreFourCal(4,2)
print(a.add())
print(a.mul())
print(a.sub())
print(a.div())
# Out:
# 6
# 8
# 2
# 2.0

# %%
class MoreFourCal(FourCal):
    def pow(self):
        result= self.first** self.second
        return result
a= MoreFourCal(4,2)
a.pow()
# Out:
# 16

# %%
a=FourCal(4,0)
a.div
# Out:
# <bound method FourCal.div of <__main__.FourCal object at 0x000001811B7E8070>>

# %%
class SafeFourCal(FourCal):
    def div(self):
        if self.second ==0:
            return 0
        else:
            return self.first/ self.second
a= SafeFourCal(4,0)
a.div()
# Out:
# 0

# %%
class Family:
    lastname="김"
print(Family.lastname)
# Out:
# 김

# %%
a= Family()
b= Family()
print(a.lastname)
print(b.lastname)
# Out:
# 김
# 김

# %%
Family.lastname="박"
print(a.lastname)
print(b.lastname)
# Out:
# 박
# 박

# %%
id(Family.lastname)
id(a.lastname)
id(b.lastname)
# Out:
# 1654026972496
